# %%
# Quick test
from battle_royale import load_student_agents

agents = load_student_agents("student_agents")
print(f"Loaded {len(agents)} agents successfully!")
for agent in agents:
    print(f"  - {agent.name}")
# Out:
# 📂 Loading student agents from: student_agents
# ======================================================================
#
# Found 1 Python files and 21 JSON files
#
# ✅ King kong                      from dougdahl_tournament_agent.py
# ✅ Trust Builder                  from alex_brown_agent.json (JSON)
# ✅ Relationship Keeper            from alex_singh_agent.json (JSON)
# ✅ Risk Manager                   from bailey_gonzalez_agent.json (JSON)
# ✅ Stable Cooperator              from casey_thomas_agent.json (JSON)
# ✅ Balanced Trader                from casey_wong_agent.json (JSON)
# ✅ Betrayal Detector              from elliot_lopez_agent.json (JSON)
# ✅ Game Theory Expert             from elliot_wong_agent.json (JSON)
# ✅ Strategic Dove                 from finley_lee_agent.json (JSON)
# ✅ Equilibrium Finder             from hayden_gonzalez_agent.json (JSON)
# ✅ Quick Retaliator               from hayden_smith_agent.json (JSON)
# ✅ Cooperative Hawk               from jesse_garcia_agent.json (JSON)
# ✅ Dynamic Responder              from jordan_thomas_agent.json (JSON)
# ✅ Profit Maximizer               from logan_brown_agent.json (JSON)
# ✅ Reputation Defender            from morgan_chen_agent.json (JSON)
# ✅ Chaos Agent                    from morgan_lee_agent.json (JSON)
# ✅ Adaptive Survivor              from morgan_smith_agent.json (JSON)
# ✅ My Evolved Agent               from my_tournament_agent.json (JSON)
# ✅ Ruthless Optimizer             from quinn_brown_agent.json (JSON)
# ✅ Pattern Matcher                from quinn_martin_agent.json (JSON)
# ✅ Nash Seeker                    from taylor_gonzalez_agent.json (JSON)
# ✅ Opportunist Prime              from taylor_jackson_agent.json (JSON)
#
# 📊 Total agents loaded: 22
# ======================================================================
#
# Loaded 22 agents successfully!
#   - King kong
#   - Trust Builder
#   - Relationship Keeper
#   - Risk Manager
#   - Stable Cooperator
#   - Balanced Trader
#   - Betrayal Detector
#   - Game Theory Expert
#   - Strategic Dove
#   - Equilibrium Finder
#   - Quick Retaliator
#   - Cooperative Hawk
#   - Dynamic Responder
#   - Profit Maximizer
#   - Reputation Defender
#   - Chaos Agent
#   - Adaptive Survivor
#   - My Evolved Agent
#   - Ruthless Optimizer
#   - Pattern Matcher
#   - Nash Seeker
#   - Opportunist Prime

# %%
"""
Unit 6: Agent Battle Royale Tournament
"""

from battle_royale import run_battle_royale
import webbrowser
import os

print("🎮 Starting Unit 6 Tournament...")
print("This will generate:")
print("  1. tournament_results.json (raw data)")
print("  2. tournament_dashboard.html (interactive explorer)")
print("  3. tournament_bracket.png (bracket image)")
print("\n" + "="*70 + "\n")

# Run tournament
bracket_champ, rr_tournament, all_agents = run_battle_royale(
    folder_path="student_agents",
    bracket_rounds=100,
    rr_rounds=100,
    num_tournaments=3,
    save_bracket=True
)

print("\n🎉 Done! Opening dashboard in browser...")

# Automatically open the HTML file in default browser
html_file = "tournament_dashboard.html"
if os.path.exists(html_file):
    file_path = os.path.abspath(html_file)
    webbrowser.open('file://' + file_path)
    print(f"✅ Dashboard opened in browser!")
    print(f"   If it didn't open, manually open: {html_file}")
else:
    print(f"❌ Could not find {html_file}")
# Out:
# 🎮 Starting Unit 6 Tournament...
# This will generate:
#   1. tournament_results.json (raw data)
#   2. tournament_dashboard.html (interactive explorer)
#   3. tournament_bracket.png (bracket image)
#
# ======================================================================
#
#
# ████████╗██╗  ██╗███████╗    ██╗   ██╗██╗  ████████╗██╗███╗   ███╗ █████╗ ████████╗███████╗
# ╚══██╔══╝██║  ██║██╔════╝    ██║   ██║██║  ╚══██╔══╝██║████╗ ████║██╔══██╗╚══██╔══╝██╔════╝
#    ██║   ███████║█████╗      ██║   ██║██║     ██║   ██║██╔████╔██║███████║   ██║   █████╗
#    ██║   ██╔══██║██╔══╝      ██║   ██║██║     ██║   ██║██║╚██╔╝██║██╔══██║   ██║   ██╔══╝
#    ██║   ██║  ██║███████╗    ╚██████╔╝███████╗██║   ██║██║ ╚═╝ ██║██║  ██║   ██║   ███████╗
#    ╚═╝   ╚═╝  ╚═╝╚══════╝     ╚═════╝ ╚══════╝╚═╝   ╚═╝╚═╝     ╚═╝╚═╝  ╚═╝   ╚═╝   ╚══════╝
#
#  █████╗  ██████╗ ███████╗███╗   ██╗████████╗    ██████╗  █████╗ ████████╗████████╗██╗     ███████╗
# ██╔══██╗██╔════╝ ██╔════╝████╗  ██║╚══██╔══╝    ██╔══██╗██╔══██╗╚══██╔══╝╚══██╔══╝██║     ██╔════╝
# ███████║██║  ███╗█████╗  ██╔██╗ ██║   ██║       ██████╔╝███████║   ██║      ██║   ██║     █████╗
# ██╔══██║██║   ██║██╔══╝  ██║╚██╗██║   ██║       ██╔══██╗██╔══██║   ██║      ██║   ██║     ██╔══╝
# ██║  ██║╚██████╔╝███████╗██║ ╚████║   ██║       ██████╔╝██║  ██║   ██║      ██║   ███████╗███████╗
# ╚═╝  ╚═╝ ╚═════╝ ╚══════╝╚═╝  ╚═══╝   ╚═╝       ╚═════╝ ╚═╝  ╚═╝   ╚═╝      ╚═╝   ╚══════╝╚══════╝
#                                     UNIT 6: THE SHOWDOWN
#
# 📂 Loading student agents from: student_agents
# ======================================================================
#
# Found 1 Python files and 21 JSON files
#
# ✅ King kong                      from dougdahl_tournament_agent.py
# ✅ Trust Builder                  from alex_brown_agent.json (JSON)
# ✅ Relationship Keeper            from alex_singh_agent.json (JSON)
# ✅ Risk Manager                   from bailey_gonzalez_agent.json (JSON)
# ✅ Stable Cooperator              from casey_thomas_agent.json (JSON)
# ✅ Balanced Trader                from casey_wong_agent.json (JSON)
# ✅ Betrayal Detector              from elliot_lopez_agent.json (JSON)
# ✅ Game Theory Expert             from elliot_wong_agent.json (JSON)
# ✅ Strategic Dove                 from finley_lee_agent.json (JSON)
# ✅ Equilibrium Finder             from hayden_gonzalez_agent.json (JSON)
# ✅ Quick Retaliator               from hayden_smith_agent.json (JSON)
# ✅ Cooperative Hawk               from jesse_garcia_agent.json (JSON)
# ✅ Dynamic Responder              from jordan_thomas_agent.json (JSON)
# ✅ Profit Maximizer               from logan_brown_agent.json (JSON)
# ✅ Reputation Defender            from morgan_chen_agent.json (JSON)
# ✅ Chaos Agent                    from morgan_lee_agent.json (JSON)
# ✅ Adaptive Survivor              from morgan_smith_agent.json (JSON)
# ✅ My Evolved Agent               from my_tournament_agent.json (JSON)
# ✅ Ruthless Optimizer             from quinn_brown_agent.json (JSON)
# ✅ Pattern Matcher                from quinn_martin_agent.json (JSON)
# ✅ Nash Seeker                    from taylor_gonzalez_agent.json (JSON)
# ✅ Opportunist Prime              from taylor_jackson_agent.json (JSON)
#
# 📊 Total agents loaded: 22
# ======================================================================
#
#
# ======================================================================
# 🏆 BRACKET TOURNAMENT: SINGLE ELIMINATION
# ======================================================================
#
# 🎲 22 agents randomly seeded
# 🏟️  5 rounds until champion
#
# ======================================================================
# ⚔️  ROUND 1
# ======================================================================
#
# ✅ Risk Manager              defeats Dynamic Responder         (179-119)
# ✅ Adaptive Survivor         defeats Stable Cooperator         (174-89)
# ✅ Trust Builder             defeats Chaos Agent               (150-105)
# ✅ Nash Seeker               defeats Ruthless Optimizer        (151-106)
# 🤝 TIE: My Evolved Agent vs Relationship Keeper (135-135) - SUDDEN DEATH!
# ⚡ My Evolved Agent          wins sudden death! (30-30)
# ✅ King kong                 defeats Game Theory Expert        (159-134)
# 🤝 TIE: Pattern Matcher vs Equilibrium Finder (182-182) - SUDDEN DEATH!
# ⚡ Equilibrium Finder        wins sudden death! (12-27)
# ✅ Reputation Defender       defeats Betrayal Detector         (161-131)
# ✅ Cooperative Hawk          defeats Profit Maximizer          (133-123)
# ✅ Opportunist Prime         defeats Quick Retaliator          (145-130)
# ✅ Strategic Dove            defeats Balanced Trader           (133-103)
#
# ======================================================================
# ⚔️  ROUND 2
# ======================================================================
#
# ✅ Adaptive Survivor         defeats Risk Manager              (130-95)
# ✅ Trust Builder             defeats Nash Seeker               (110-105)
# 🤝 TIE: My Evolved Agent vs King kong (299-299) - SUDDEN DEATH!
# ⚡ My Evolved Agent          wins sudden death! (30-30)
# ✅ Reputation Defender       defeats Equilibrium Finder        (181-116)
# ✅ Opportunist Prime         defeats Cooperative Hawk          (162-147)
# 👋 Strategic Dove            gets a bye (advances automatically)
#
# ======================================================================
# ⚔️  ROUND 3
# ======================================================================
#
# ✅ Adaptive Survivor         defeats Trust Builder             (132-97)
# ✅ My Evolved Agent          defeats Reputation Defender       (139-104)
# ✅ Strategic Dove            defeats Opportunist Prime         (125-100)
#
# ======================================================================
# ⚔️  ROUND 4
# ======================================================================
#
# ✅ Adaptive Survivor         defeats My Evolved Agent          (109-104)
# 👋 Strategic Dove            gets a bye (advances automatically)
#
# ======================================================================
# 🏆 FINALS
# ======================================================================
#
# ✅ Adaptive Survivor         defeats Strategic Dove            (114-99)
#
# ======================================================================
# 🎉 TOURNAMENT CHAMPION 🎉
# ======================================================================
#
# 👑 Adaptive Survivor
#    by Morgan Smith
#
#    Survived 5 rounds of elimination!
# ======================================================================
#
# ✅ Bracket saved to: tournament_bracket.png
# ======================================================================
# 📊 COMPREHENSIVE ROUND-ROBIN TOURNAMENT
# ======================================================================
#
# Every agent plays every other agent 3 time(s)
# Each match: 100 rounds
# Total matches: 1386
# ======================================================================
#
# Running 3 tournament(s) with 22 agents...
#
# Tournament 1/3
#
# Tournament 2/3
#
# Tournament 3/3
# Tournament complete!
#
# ======================================================================
# 🏆 FINAL COMPREHENSIVE RANKINGS
# ======================================================================
#
# 🥇  1. Stable Cooperator             : 10,221 points
# 🥈  2. My Evolved Agent              : 10,030 points
# 🥉  3. King kong                     : 9,865 points
#     4. Relationship Keeper           : 9,791 points
#     5. Chaos Agent                   : 9,621 points
#     6. Adaptive Survivor             : 9,120 points  👑 BRACKET CHAMPION
#     7. Profit Maximizer              : 9,092 points
#     8. Trust Builder                 : 9,089 points
#     9. Balanced Trader               : 8,999 points
#    10. Nash Seeker                   : 8,957 points
#    11. Opportunist Prime             : 8,939 points
#    12. Strategic Dove                : 8,825 points
#    13. Risk Manager                  : 8,754 points
#    14. Quick Retaliator              : 8,653 points
#    15. Reputation Defender           : 8,615 points
#    16. Cooperative Hawk              : 8,378 points
#    17. Betrayal Detector             : 8,293 points
#    18. Pattern Matcher               : 8,218 points
#    19. Dynamic Responder             : 8,190 points
#    20. Ruthless Optimizer            : 8,130 points
#    21. Game Theory Expert            : 8,076 points
#    22. Equilibrium Finder            : 7,790 points
#
# ======================================================================
# 📈 DETAILED PERFORMANCE STATISTICS
# ======================================================================
#
# Agent                           Wins  Win Rate  Avg Score
# ----------------------------------------------------------------------
# Stable Cooperator                  6     4.8%      157.9
# My Evolved Agent                  99    78.6%      159.3
# King kong                         54    42.9%      162.6
# Relationship Keeper              109    86.5%      153.1
# Chaos Agent                       59    46.8%      150.6
# Adaptive Survivor                125    99.2%      145.7
# Profit Maximizer                  87    69.0%      141.4
# Trust Builder                     82    65.1%      143.8
# Balanced Trader                   72    57.1%      141.5
# Nash Seeker                      102    81.0%      142.2
# Opportunist Prime                 75    59.5%      139.6
# Strategic Dove                   101    80.2%      141.1
# Risk Manager                      55    43.7%      138.8
# Quick Retaliator                  53    42.1%      134.5
# Reputation Defender               56    44.4%      138.9
# Cooperative Hawk                  44    34.9%      131.9
# Betrayal Detector                 33    26.2%      131.2
# Pattern Matcher                    6     4.8%      132.3
# Dynamic Responder                 37    29.4%      131.0
# Ruthless Optimizer                36    28.6%      130.9
# Game Theory Expert                14    11.1%      127.3
# Equilibrium Finder                 9     7.1%      124.8
#
# ======================================================================
# 🤔 BRACKET vs ROUND-ROBIN COMPARISON
# ======================================================================
#
# 👑 Bracket Champion:      Adaptive Survivor
#    Round-Robin Rank:      #6
#
# 🏆 Round-Robin Champion:  Stable Cooperator
#
# 💡 Lesson: Single elimination is exciting but can be random!
#    The most consistent performer wins the comprehensive tournament.
#
# ======================================================================
# 🏅 SUPERLATIVE AWARDS
# ======================================================================
#
# 🤝 MOST COOPERATIVE: King kong
#    Average score: 162.6 (achieves mutual cooperation)
#
# ⚔️  MOST AGGRESSIVE: Adaptive Survivor
#    Wins: 125 (99.2% win rate)
#
# 📊 MOST CONSISTENT: Quick Retaliator
#    Score std dev: 29.2 (very predictable)
#
# 🎯 BIGGEST UPSET: Equilibrium Finder
#    Defeated Stable Cooperator (ranked 21 spots higher)
#
# 💥 GLASS CANNON: Opportunist Prime
#    Scored 309 points vs Stable Cooperator in single game
#
# 🎖️  PARTICIPATION TROPHY: Equilibrium Finder
#    Finished last but showed up! (7,790 points)
# ======================================================================
#
# ======================================================================
# 👥 ALL STUDENT AGENTS - FIND YOURS!
# ======================================================================
#
# Student                   Agent Name                       Rank      Score
# --------------------------------------------------------------------------------
# 🥇 Casey Thomas              Stable Cooperator                 1     10,221
# 🥈 my_tournament_agent       My Evolved Agent                  2     10,030
# 🥉 Doug Dahl                 King kong                         3      9,865
#    Alex Singh                Relationship Keeper               4      9,791
#    Morgan Lee                Chaos Agent                       5      9,621
#    Morgan Smith              Adaptive Survivor                 6      9,120
#    Logan Brown               Profit Maximizer                  7      9,092
#    Alex Brown                Trust Builder                     8      9,089
#    Casey Wong                Balanced Trader                   9      8,999
#    Taylor Gonzalez           Nash Seeker                      10      8,957
#    Taylor Jackson            Opportunist Prime                11      8,939
#    Finley Lee                Strategic Dove                   12      8,825
#    Bailey Gonzalez           Risk Manager                     13      8,754
#    Hayden Smith              Quick Retaliator                 14      8,653
#    Morgan Chen               Reputation Defender              15      8,615
#    Jesse Garcia              Cooperative Hawk                 16      8,378
#    Elliot Lopez              Betrayal Detector                17      8,293
#    Quinn Martin              Pattern Matcher                  18      8,218
#    Jordan Thomas             Dynamic Responder                19      8,190
#    Quinn Brown               Ruthless Optimizer               20      8,130
#    Elliot Wong               Game Theory Expert               21      8,076
#    Hayden Gonzalez           Equilibrium Finder               22      7,790
#
# ======================================================================
# 💾 EXPORTING TOURNAMENT DATA
# ======================================================================
#
# ✅ Tournament data exported to: tournament_results.json
#    Total agents: 22
#    Total matches: 1386
#    File size: 234.5 KB
#
# ======================================================================
# 🌐 GENERATING INTERACTIVE DASHBOARD
# ======================================================================
#
# ✅ Interactive dashboard generated: tournament_dashboard.html
#    Open this file in your browser to explore results!
#    Features:
#      - Searchable tables
#      - Tabbed interface
#      - Bracket visualization
#      - Superlative awards
#
# 🎉 Done! Opening dashboard in browser...
# ✅ Dashboard opened in browser!
#    If it didn't open, manually open: tournament_dashboard.html

# %%
# ============================================================================
# REFLECTION QUESTIONS
# ============================================================================

print("\n" + "="*70)
print("📝 REFLECTION QUESTIONS FOR YOUR WRITEUP")
print("="*70)
print("""
Look at the "ALL STUDENT AGENTS" table above to find your ranking.

1. Tournament Performance Analysis
   - What was your agent's final rank?
   - How did you perform in bracket vs. round-robin?
   - Were the results similar or different? Why might that be?

2. Strategy Analysis
   - Look at the top 3 agents. What strategies do they use?
   - Compare them to your agent's strategy (your evolved genes)
   - What made the winning strategies successful?

3. Bracket vs. Round-Robin
   - Was the Bracket Champion the same as Round-Robin Champion?
   - If different, what does this teach you about tournament formats?
   - Which format better reflects true agent quality? Why?

4. Superlative Awards
   - Which superlative award did your agent win (if any)?
   - What trade-offs do different strategies make?
   - Would you rather have high win rate or high total score?

5. Generalization Lesson
   - Your agent was trained on 10 random opponents in Unit 5
   - It competed against 20+ agents here (most unseen)
   - How did this affect your agent's performance?
   - What would you change if you could redesign for THIS environment?

6. Game Theory Insights
   - Is there a "best" strategy that beats everyone?
   - Why or why not? (Hint: Think about opponent diversity)
   - What real-world situations mirror this tournament dynamic?

SUBMISSION: Write a 1-2 page reflection answering these questions.
Include your rank, total score, and what you learned about
evolutionary optimization and game theory.
""")

print("\n" + "="*70)
print("🎉 THANK YOU FOR PARTICIPATING!")
print("="*70)
